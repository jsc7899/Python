# %%
sys = signal.TransferFunction([1,0,0], [1,0,0.8])
w, mag, phase = sys.bode()
plt.figure()
plt.semilogx(w, mag)    # Bode magnitude plot
plt.title('Magnitude')
plt.figure()
plt.semilogx(w, phase)  # Bode phase plot
plt.title('Phase')
plt.show()
